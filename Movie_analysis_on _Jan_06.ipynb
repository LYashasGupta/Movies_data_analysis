# %%
tup = 1, 2, 3

print(type(tup))
# Out:
# <class 'tuple'>

# %%
My_str_1 = "hello"
My_str_1
# Out:
# 'hello'

# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
links = pd.read_csv(r"D:\movie_data\links.csv")
movies = pd.read_csv(r"D:\movie_data\movies.csv")
ratings = pd.read_csv(r"D:\movie_data\ratings.csv")
tags = pd.read_csv(r"D:\movie_data\tags.csv")

# %%
movies.shape
# Out:
# (9742, 3)

# %%
ratings.shape
# Out:
# (100836, 4)

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
ratings.nunique()
# Out:
# userId         610
# movieId       9724
# rating          10
# timestamp    85043
# dtype: int64

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.head(5)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
ratings.rating.value_counts()
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: rating, dtype: int64

# %%
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
tags.nunique()
# Out:
# userId         58
# movieId      1572
# tag          1589
# timestamp    3411
# dtype: int64

# %%
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
df = pd.merge(movies,tags,how = "inner",on = "movieId")

# %%
df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        2    Jumanji (1995)                   Adventure|Children|Fantasy
# 4        2    Jumanji (1995)                   Adventure|Children|Fantasy
#
#    userId               tag   timestamp
# 0     336             pixar  1139045764
# 1     474             pixar  1137206825
# 2     567               fun  1525286013
# 3      62           fantasy  1528843929
# 4      62  magic board game  1528843932

# %%
df[df["title"] == "Matrix, The (1999)"]
# Out:
#       movieId               title                  genres  userId  \
# 1313     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     424
# 1314     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     424
# 1315     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     474
# 1316     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     537
# 1317     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     537
#
#                      tag   timestamp
# 1313        martial arts  1457842912
# 1314              sci-fi  1457842899
# 1315  alternate universe  1137204991
# 1316          philosophy  1424141098
# 1317    post apocalyptic  1424141101

# %%
movies[movies["title"] == "Matrix, The (1999)"]
# Out:
#       movieId               title                  genres
# 1939     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df1 = pd.merge(movies,ratings,how = "inner",on = "movieId")

# %%
df1.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0       1     4.0   964982703
# 1       5     4.0   847434962
# 2       7     4.5  1106635946
# 3      15     2.5  1510577970
# 4      17     4.5  1305696483

# %%
a = df1[df1["title"] == "Fight Club (1999)"]

# %%
a.head()
# Out:
#        movieId              title                       genres  userId  \
# 49835     2959  Fight Club (1999)  Action|Crime|Drama|Thriller       1
# 49836     2959  Fight Club (1999)  Action|Crime|Drama|Thriller       4
# 49837     2959  Fight Club (1999)  Action|Crime|Drama|Thriller      10
# 49838     2959  Fight Club (1999)  Action|Crime|Drama|Thriller      15
# 49839     2959  Fight Club (1999)  Action|Crime|Drama|Thriller      16
#
#        rating   timestamp
# 49835     5.0   964983282
# 49836     2.0   945078528
# 49837     0.5  1455356582
# 49838     2.5  1510571747
# 49839     3.5  1377476874

# %%
s = a["rating"]
ax = s.plot.kde()

# %%
grouped_data = df1.groupby('movieId').agg({'rating': ['count', 'mean']})

# %%
grouped_data.columns = ['rating_count', 'rating_mean']

# %%
grouped_data.head()
# Out:
#          rating_count  rating_mean
# movieId
# 1                 215     3.920930
# 2                 110     3.431818
# 3                  52     3.259615
# 4                   7     2.357143
# 5                  49     3.071429

# %%
result_df = pd.merge(movies, grouped_data, on='movieId', how='inner')

# %%
result_df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9719   193581  Black Butler: Book of the Atlantic (2017)
# 9720   193583               No Game No Life: Zero (2017)
# 9721   193585                               Flint (2017)
# 9722   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9723   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  rating_count  rating_mean
# 0     Adventure|Animation|Children|Comedy|Fantasy           215     3.920930
# 1                      Adventure|Children|Fantasy           110     3.431818
# ...

# %%
filtered_movies = result_df[result_df['rating_count'] > 50]

# %%
filtered_movies
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 1           2                    Jumanji (1995)
# 2           3           Grumpier Old Men (1995)
# 5           6                       Heat (1995)
# 6           7                    Sabrina (1995)
# ...       ...                               ...
# 8287   106782   Wolf of Wall Street, The (2013)
# 8354   109374  Grand Budapest Hotel, The (2014)
# 8358   109487               Interstellar (2014)
# 8457   112852    Guardians of the Galaxy (2014)
# 8673   122904                   Deadpool (2016)
#
#                                            genres  rating_count  rating_mean
# 0     Adventure|Animation|Children|Comedy|Fantasy           215     3.920930
# 1                      Adventure|Children|Fantasy           110     3.431818
# 2                                  Comedy|Romance            52     3.259615
# 5                           Action|Crime|Thriller           102     3.946078
# ...

# %%
filtered_movies["rating_mean"].max()
# Out:
# 4.429022082018927

# %%
filtered_movies[filtered_movies["rating_mean"] == filtered_movies["rating_mean"].max()]
# Out:
#      movieId                             title       genres  rating_count  \
# 277      318  Shawshank Redemption, The (1994)  Crime|Drama           317
#
#      rating_mean
# 277     4.429022

# %%
sorted_movies = filtered_movies.sort_values(by='rating_count', ascending=False)

sorted_movies.head()
# Out:
#       movieId                             title                       genres  \
# 314       356               Forrest Gump (1994)     Comedy|Drama|Romance|War
# 277       318  Shawshank Redemption, The (1994)                  Crime|Drama
# 257       296               Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller
# 510       593  Silence of the Lambs, The (1991)        Crime|Horror|Thriller
# 1938     2571                Matrix, The (1999)       Action|Sci-Fi|Thriller
#
#       rating_count  rating_mean
# 314            329     4.164134
# 277            317     4.429022
# 257            307     4.197068
# 510            279     4.161290
# 1938           278     4.192446

# %%
sorted_movies[sorted_movies["genres"] == "Action|Sci-Fi|Thriller"]
# Out:
#       movieId                         title                  genres  \
# 1938     2571            Matrix, The (1999)  Action|Sci-Fi|Thriller
# 938      1240        Terminator, The (1984)  Action|Sci-Fi|Thriller
# 474       541           Blade Runner (1982)  Action|Sci-Fi|Thriller
# 2632     3527               Predator (1987)  Action|Sci-Fi|Thriller
# 144       172        Johnny Mnemonic (1995)  Action|Sci-Fi|Thriller
# 6192    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
#
#       rating_count  rating_mean
# 1938           278     4.192446
# 938            131     3.896947
# 474            124     4.100806
# 2632            61     3.581967
# 144             53     2.679245
# 6192            52     3.355769

# %%
result_df[result_df["genres"] == "Sci-Fi"]
# Out:
#       movieId                                              title  genres  \
# 1718     2311              2010: The Year We Make Contact (1984)  Sci-Fi
# 1901     2526                                      Meteor (1979)  Sci-Fi
# 1999     2661                    It Came from Outer Space (1953)  Sci-Fi
# 2002     2665                Earth vs. the Flying Saucers (1956)  Sci-Fi
# 2025     2698                                     Zone 39 (1997)  Sci-Fi
# 2504     3354                             Mission to Mars (2000)  Sci-Fi
# 3116     4198                     Battle Beyond the Stars (1980)  Sci-Fi
# 3517     4813                         When Worlds Collide (1951)  Sci-Fi
# 3595     4942                       Angry Red Planet, The (1959)  Sci-Fi
# 3888     5468                   20 Million Miles to Earth (1957)  Sci-Fi
# 4116     5919                                     Android (1982)  Sci-Fi
# 4308     6302                        Beginning of the End (1957)  Sci-Fi
# ...

# %%
filtered_movies
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 1           2                    Jumanji (1995)
# 2           3           Grumpier Old Men (1995)
# 5           6                       Heat (1995)
# 6           7                    Sabrina (1995)
# ...       ...                               ...
# 8287   106782   Wolf of Wall Street, The (2013)
# 8354   109374  Grand Budapest Hotel, The (2014)
# 8358   109487               Interstellar (2014)
# 8457   112852    Guardians of the Galaxy (2014)
# 8673   122904                   Deadpool (2016)
#
#                                            genres  rating_count  rating_mean
# 0     Adventure|Animation|Children|Comedy|Fantasy           215     3.920930
# 1                      Adventure|Children|Fantasy           110     3.431818
# 2                                  Comedy|Romance            52     3.259615
# 5                           Action|Crime|Thriller           102     3.946078
# ...
